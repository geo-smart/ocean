# %%
from NotebookModule import *
# Out:
# For 2021, month of January, we have...
# 31 days or 279 possible profiles
# There were, over this time, in fact...
# 256 profiles; 28 at local midnight and 29 at local noon

# %%
ds = xr.open_dataset('../../data/rca/pCO2/ooi-rs01sbps-sf01a-4f-pco2wa101_9470_ff1d_d220.nc')
ds = ds.swap_dims({'row': 'time'})
ds = ds.rename({'partial_pressure_of_carbon_dioxide_in_sea_water_profiler_depth_enabled':'pco2'})
ds.z.plot()
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 38154)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-10-07T01:05:00 ... 2022-03-08T22:33:00
# Data variables:
#     pco2     (time) float64 ...
#     z        (time) float64 ...
# Attributes: (12/44)
#     cdm_altitude_proxy:            z
#     cdm_data_type:                 TimeSeriesProfile
#     cdm_profile_variables:         time
#     cdm_timeseries_variables:      station,longitude,latitude
#     contributor_email:             feedback@axiomdatascience.com
#     contributor_name:              Axiom Data Science
#     ...                            ...
#     standard_name_vocabulary:      CF Standard Name Table v72
#     station_id:                    104294
#     summary:                       Timeseries data from 'Regional Cabled Arra...
#     time_coverage_end:             2022-03-08T22:33:00Z
#     time_coverage_start:           2014-10-07T01:05:00Z
# ...

# %%
ta0 = dt64_from_doy(2021, 60)
ta1 = dt64_from_doy(2021, 91)
ds.sel(time=slice(ta0,  ta1)).z.plot()

# %%
ds.sel(time=slice(ta0,  ta1)).to_netcdf("../RepositoryData/rca/pCO2/osb_pco2_march2021.nc")

# %%
ds.pco2.mean()
# Out:
# <xarray.DataArray 'pco2' ()>
# array(2906.322521)
