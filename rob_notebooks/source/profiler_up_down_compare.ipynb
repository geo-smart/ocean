# %% [markdown]
# # Introduction
#
# This notebook compares profile *ascent* to *descent* observations.
#
# Data are loaded using the **`NotebookModule.py`** import.
#
#
# - p = profile metadata
# - A, B, C = Fluorometer
# - T, S, O = CTD
# - H = pH
# - I = Spectral Irradiance
# - N = Nitrate
# - P = PAR
# - R = pCO2

# %%
from NotebookModule import *

# %% [markdown]
# ### Ascent compared to descent
#
#
# In what follows the *descent* is always the lighter of the two colors, *ascent* thus being darker.

# %%
CompareAscentDescent(p, T, S, O, A, B, C)

# %% [markdown]
# - More labels needed: Dates, axes
#
#
# #### Profiler at rest ~ 200m platform
#
# - March 2022 -> DataRepository/rca; and then x-axis time, y-axis T/S/O etc
